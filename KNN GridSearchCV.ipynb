# %%
from sklearn import svm, datasets
import pandas as pd
import numpy  as np
from sklearn.model_selection import GridSearchCV

#ML
from sklearn.neighbors import KNeighborsClassifier

#import libraries for model validation
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import LeavePOut
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import cross_val_score

# %%
# load the training data from iris.txt
df_training = pd.read_csv('iris.csv', delim_whitespace=True)

# %%
iris = df_training
iris = datasets.load_iris()

# %%
iris.data[:3]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2]])

# %%
iris.target[:3]
# Out:
# array([0, 0, 0])

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...

# %%
x = iris.data
y = iris.target

# %%
#instantiate the KNN classifer
#{'metric': 'minkowksi', 'n_neighbors': 5, 'p':2, 'weights': 'uniform'}
clf = KNeighborsClassifier()

# %%
#Get the KNN parameters
clf.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
#Get KNN parameter keys
clf.get_params().keys()
#Returns a dictionary and this will help you set range values.
# Out:
# dict_keys(['algorithm', 'leaf_size', 'metric', 'metric_params', 'n_jobs', 'n_neighbors', 'p', 'weights'])

# %%
n_neighbors = [3,5,7,9,11,13,15,19,23,29]
algos = ['ball_tree', 'kd_tree']
dist_metric = ['minkowksi']
p_root = [1,2,3,4,5]
weights = ['uniform', 'distance']
leaf_size = [15,30,40,50,60,70]

# %%
#Define the parameters dict
parameters = dict(
                n_neighbors = n_neighbors,
                #algorithm = algos,
                metric = dist_metric,
                p = p_root,
                weights = weights,
                #Leaf_size = leaf_size
              )

print(parameters)
# Out:
# {'n_neighbors': [3, 5, 7, 9, 11, 13, 15, 19, 23, 29], 'metric': ['minkowksi'], 'p': [1, 2, 3, 4, 5], 'weights': ['uniform', 'distance']}

# %%
# define splits 
n_splits = 5

kf = KFold(n_splits = n_splits, shuffle=True, random_state=100)
#skf = StratifiedKFold(n_splits = n_splits, shuffle=True, random_state=100)

# %%
#Instantiate the grid search CV - a for loop
grid = GridSearchCV(estimator = clf,
                    param_grid = parameters,
                    scoring = 'accuracy', 
                    cv=kf,
                    verbose=2)

# %%
#fit the data to the grid object 
grid.fit(x,y)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END metric=minkowksi, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=3, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=5, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=7, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=9, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=11, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=13, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=15, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=19, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=23, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=1, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=1, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=2, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=2, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=3, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=3, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=4, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=4, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=5, weights=uniform; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=5, weights=distance; total time=   0.0s
# [CV] END metric=minkowksi, n_neighbors=29, p=5, weights=distance; total time=   0.0s
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 500 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 500 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py", line 198, in fit
#     return self._fit(X, y)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py", line 437, in _fit
#     self._check_algorithm_metric()
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py", line 374, in _check_algorithm_metric
#     raise ValueError(
# ValueError: Metric 'minkowksi' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [82], in <cell line: 2>()
#       1 #fit the data to the grid object
# ----> 2 grid.fit(x,y)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:926, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     924 refit_start_time = time.time()
#     925 if y is not None:
# --> 926     self.best_estimator_.fit(X, y, **fit_params)
#     927 else:
#     928     self.best_estimator_.fit(X, **fit_params)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:198, in KNeighborsClassifier.fit(self, X, y)
#     179 """Fit the k-nearest neighbors classifier from the training dataset.
#     180
#     181 Parameters
#    (...)
#     194     The fitted k-nearest neighbors classifier.
#     195 """
#     196 self.weights = _check_weights(self.weights)
# --> 198 return self._fit(X, y)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py:437, in NeighborsBase._fit(self, X, y)
#     434     if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
#     435         X = self._validate_data(X, accept_sparse="csr")
# --> 437 self._check_algorithm_metric()
#     438 if self.metric_params is None:
#     439     self.effective_metric_params_ = {}
#
# File /opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_base.py:374, in NeighborsBase._check_algorithm_metric(self)
#     367         raise ValueError(
#     368             "kd_tree does not support callable metric '%s'"
#     369             "Function call overhead will result"
#     370             "in very poor performance."
#     371             % self.metric
#     372         )
#     373 elif self.metric not in VALID_METRICS[alg_check]:
# --> 374     raise ValueError(
#     375         "Metric '%s' not valid. Use "
#     376         "sorted(sklearn.neighbors.VALID_METRICS['%s']) "
#     377         "to get valid options. "
#     378         "Metric can also be a callable function." % (self.metric, alg_check)
#     379     )
#     381 if self.metric_params is not None and "p" in self.metric_params:
#     382     if self.p is not None:
#
# ValueError: Metric 'minkowksi' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.

# %%
#What are the best parameters that you got?
print('Estimator: \n',   grid.best_estimator_)
print('Best params : \n', grid.best_params_)
print(grid.classes_)
print(grid.best_score_)
# Out:
# Estimator:
#  KNeighborsClassifier(metric='minkowksi', n_neighbors=3, p=1)
# Best params :
#  {'metric': 'minkowksi', 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# [0 1 2]
# nan
